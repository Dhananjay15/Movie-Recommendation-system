# %%
api_key='8265bd1679663a7ea12ac168da84d2e8'
import requests
import datetime
import time
import pandas as pd
from tmdbv3api import TMDb
from tmdbv3api import Movie
tmdb=TMDb()
movie = Movie()
TMDb.api_key= api_key
tmdb.language = 'en'
tmdb.debug = True

# %%
df = pd.read_csv('./indian_movies_data.csv')
df
# Out:
#       adult                     backdrop_path           genre_ids       id  \
# 0     False  /kQM7o3NIkruIZLoQ9E2XzZQ8Ujl.jpg        [28, 35, 80]   783461
# 1     False  /7w06baRS9VPm5RYz8lawTCLiR4j.jpg        [28, 80, 53]   592508
# 2     False  /4r3iEz4CsRWm7KTrFrESrKkv7GU.jpg     [18, 35, 10749]   601635
# 3     False  /3X44M96PsggERutUGrYhHXuaHsl.jpg     [35, 18, 10751]   729700
# 4     False  /aFGPUmbgGoAt93WP3WYsAPa0Yv8.jpg            [18, 35]    20453
# ...     ...                               ...                 ...      ...
# 5894  False  /eVyieAGsQw2wofOhBCPhKRaz8N7.jpg         [10749, 18]    20687
# 5895  False                               NaN                [18]    20491
# 5896  False                               NaN  [18, 10402, 10749]    20292
# 5897  False                               NaN     [35, 18, 10749]    16352
# 5898  False                               NaN                  []  1012151
#
#      original_language                   original_title  \
# ...

# %%
all_cast
# Out:
# [['Shanti Sivaram Maini'],
#  ['Rohit Shetty'],
#  ['Raju Khan'],
#  ['Aanand L. Rai'],
#  ['Rajkumar Hirani'],
#  ['Monisha R Baldawa'],
#  ['Sharmishta Roy'],
#  ['Anirudh Ravichander'],
#  ['Manish Malhotra']]

# %%
DIRECTORS = []
for j in df.id:
    sid = j
    cred = requests.get("https://api.themoviedb.org/3/movie/{}?api_key=8265bd1679663a7ea12ac168da84d2e8&append_to_response=credits".format(sid)).json()
    name = []
    for i in cred['credits']['crew']:
        if i['job'] == 'Director':
            name.append(i['name'])
    DIRECTORS.append(name)

# %%
DIRECTORS
# Out:
# [['Aakash Bhatia'],
#  ['Rohit Shetty'],
#  ['Advait Chandan'],
#  ['Aanand L. Rai'],
#  ['Rajkumar Hirani'],
#  ['Ram Madhvani'],
#  ['Aditya Chopra'],
#  ['Gowtam Tinnanuri'],
#  ['Karan Johar'],
#  ['Anvita Dutt'],
#  ['Vishal Mahadkar'],
#  ['Jasmeet K Reen'],
#  ['Karan Johar'],
#  ['Sanjay Puran Singh Chauhan'],
#  ['Aamir Khan'],
#  ['Amit Saxena'],
#  ['Ribhu Dasgupta'],
#  ['Anurag Basu'],
#  ['Tarun Mansukhani'],
#  ['Akhilesh Jaiswal'],
#  ['Farah Khan'],
#  ['Nitesh Tiwari'],
#  ['Chuck Russell'],
#  ['Karan Johar'],
#  ['Sabbir Khan'],
#  ['Sameer Saxena'],
#  ['Yash Chopra'],
#  ['Sanjay Leela Bhansali'],
#  ['Deven Bhojani'],
#  ['Gauri Shinde'],
#  ['Kunal Kohli'],
#  ['Ashutosh Gowariker'],
#  ['Aditya Chopra'],
#  ['Farah Khan'],
#  ['Ashutosh Gowariker'],
#  ['R. Balki'],
#  ['Vijay Krishna Acharya'],
#  ['Sujoy Ghosh'],
#  ['Imtiaz Ali'],
#  ['Ravi Udyawar'],
#  ['Rajkumar Hirani'],
#  ['Raj Mehta'],
#  ['Amrit'],
#  ['Rohit Shetty'],
#  ['Mayank Pushpam Singh'],
# ...

# %%
df['DIRECTORS'] = DIRECTORS

# %%
df
# Out:
#       adult                     backdrop_path           genre_ids       id  \
# 0     False  /kQM7o3NIkruIZLoQ9E2XzZQ8Ujl.jpg        [28, 35, 80]   783461
# 1     False  /7w06baRS9VPm5RYz8lawTCLiR4j.jpg        [28, 80, 53]   592508
# 2     False  /4r3iEz4CsRWm7KTrFrESrKkv7GU.jpg     [18, 35, 10749]   601635
# 3     False  /3X44M96PsggERutUGrYhHXuaHsl.jpg     [35, 18, 10751]   729700
# 4     False  /aFGPUmbgGoAt93WP3WYsAPa0Yv8.jpg            [18, 35]    20453
# ...     ...                               ...                 ...      ...
# 5894  False  /eVyieAGsQw2wofOhBCPhKRaz8N7.jpg         [10749, 18]    20687
# 5895  False                               NaN                [18]    20491
# 5896  False                               NaN  [18, 10402, 10749]    20292
# 5897  False                               NaN     [35, 18, 10749]    16352
# 5898  False                               NaN                  []  1012151
#
#      original_language                   original_title  \
# ...

# %%
df.to_csv('indian_movies_data_director.csv', header=True, index=False)
